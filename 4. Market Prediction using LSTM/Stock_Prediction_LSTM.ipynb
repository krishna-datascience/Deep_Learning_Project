# %% [markdown]
# ### Import Libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# **The data that we are going to use for this algorithm is downloaded by NSEpy API. For training our algorithm, we will be using the SBI stock prices from 1st January 2015 to 31st December 2018. For the sake of prediction, we will use the SBI stock prices for the month of January 2019**

# %%
from datetime import date
from nsepy import get_history
sbin = get_history(symbol='SBIN',
                   start=date(2015,1,1),
                   end=date(2018,12,31))

# %%
sbin
# Out:
#            Symbol Series  Prev Close    Open    High     Low    Last   Close  \
# Date
# 2015-01-01   SBIN     EQ      311.85  312.45  315.00  310.70  314.00  314.00
# 2015-01-02   SBIN     EQ      314.00  314.35  318.30  314.35  315.60  315.25
# 2015-01-05   SBIN     EQ      315.25  316.25  316.80  312.10  312.80  312.75
# 2015-01-06   SBIN     EQ      312.75  310.00  311.10  298.70  299.90  299.90
# 2015-01-07   SBIN     EQ      299.90  300.00  302.55  295.15  301.40  300.15
# 2015-01-08   SBIN     EQ      300.15  305.00  306.50  302.35  305.25  304.85
# 2015-01-09   SBIN     EQ      304.85  306.70  307.85  302.00  303.00  303.20
# 2015-01-12   SBIN     EQ      303.20  304.15  307.80  301.10  306.90  307.10
# 2015-01-13   SBIN     EQ      307.10  308.15  310.75  304.15  305.25  305.10
# 2015-01-14   SBIN     EQ      305.10  304.00  307.00  302.25  305.00  304.70
# 2015-01-15   SBIN     EQ      304.70  319.90  323.70  314.00  318.40  320.30
# 2015-01-16   SBIN     EQ      320.30  320.00  320.30  313.10  315.25  315.45
# 2015-01-19   SBIN     EQ      315.45  316.55  317.95  312.50  313.20  313.15
# 2015-01-20   SBIN     EQ      313.15  314.00  319.80  314.00  318.00  318.15
# 2015-01-21   SBIN     EQ      318.15  319.90  327.60  319.00  326.00  326.20
# 2015-01-22   SBIN     EQ      326.20  326.90  327.60  321.80  325.20  324.65
# 2015-01-23   SBIN     EQ      324.65  328.25  332.55  324.65  327.05  327.45
# 2015-01-27   SBIN     EQ      327.45  329.40  332.15  322.60  331.45  330.05
# 2015-01-28   SBIN     EQ      330.05  330.40  336.00  328.20  333.40  334.60
# 2015-01-29   SBIN     EQ      334.60  332.80  333.60  325.10  326.45  327.00
# 2015-01-30   SBIN     EQ      327.00  328.70  330.50  307.00  309.30  308.95
# 2015-02-02   SBIN     EQ      308.95  309.50  311.90  305.10  308.50  307.50
# 2015-02-03   SBIN     EQ      307.50  312.00  312.00  299.05  299.65  300.30
# 2015-02-04   SBIN     EQ      300.30  302.70  302.95  291.90  292.55  293.05
# 2015-02-05   SBIN     EQ      293.05  293.15  297.80  289.20  290.50  290.80
# 2015-02-06   SBIN     EQ      290.80  291.00  294.85  285.70  291.20  290.30
# 2015-02-09   SBIN     EQ      290.30  289.50  292.80  278.00  279.50  279.50
# 2015-02-10   SBIN     EQ      279.50  277.50  290.80  275.70  289.75  287.30
# 2015-02-11   SBIN     EQ      287.30  290.80  293.50  283.70  286.20  285.95
# 2015-02-12   SBIN     EQ      285.95  288.90  289.00  278.30  286.10  284.30
# ...           ...    ...         ...     ...     ...     ...     ...     ...
# 2018-11-16   SBIN     EQ      285.40  285.90  291.80  282.60  291.55  290.90
# 2018-11-19   SBIN     EQ      290.90  293.50  293.50  286.05  288.05  288.15
# 2018-12-28  295.43  12876558  3.804110e+14   85894             3896890
# 2018-12-31  296.50   9526067  2.824443e+14   81758             2618550
#
#             %Deliverble
# Date
# 2015-01-01       0.3059
# 2015-01-02       0.4249
# 2015-01-05       0.4208
# 2015-01-06       0.4844
# 2015-01-07       0.3743
# 2015-01-08       0.4090
# 2015-01-09       0.3692
# 2015-01-12       0.4378
# 2015-01-13       0.4375
# 2015-01-14       0.4385
# 2015-01-15       0.5452
# 2015-01-16       0.6461
# 2015-01-19       0.5451
# 2015-01-20       0.5071
# 2015-01-21       0.4785
# 2015-01-22       0.4818
# 2015-01-23       0.5392
# 2015-01-27       0.5365
# 2015-01-28       0.4863
# 2015-01-29       0.5059
# 2015-01-30       0.5758
# 2015-02-02       0.5028
# 2015-02-03       0.4305
# 2015-02-04       0.4914
# 2015-02-05       0.3427
# 2015-02-06       0.3112
# 2015-02-09       0.4004
# 2015-02-10       0.3185
# 2015-02-11       0.4371
# 2015-02-12       0.4008
# ...                 ...
# 2018-11-16       0.3399
# 2018-11-19       0.2104
# 2018-11-20       0.1605
# 2018-11-21       0.2437
# 2018-11-22       0.2732
# 2018-11-26       0.2993
# 2018-11-27       0.3554
# 2018-11-28       0.3108
# 2018-11-29       0.4190
# 2018-11-30       0.2574
# 2018-12-03       0.2789
# 2018-12-04       0.2691
# 2018-12-05       0.2244
# 2018-12-06       0.2937
# 2018-12-07       0.1474
# 2018-12-10       0.2900
# 2018-12-11       0.3072
# 2018-12-12       0.3577
# 2018-12-13       0.3313
# 2018-12-14       0.1942
# 2018-12-17       0.3797
# 2018-12-18       0.2319
# 2018-12-19       0.3453
# 2018-12-20       0.2203
# 2018-12-21       0.2396
# 2018-12-24       0.1946
# 2018-12-26       0.1352
# 2018-12-27       0.3160
# 2018-12-28       0.3026
# 2018-12-31       0.2749
#
# [989 rows x 14 columns]

# %% [markdown]
# **Make a dataframe from the above fetched data**

# %%
sbin.to_csv('SBI.csv')

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout
# Out:
# Using TensorFlow backend.

# %%
sbi_data_raw = pd.read_csv('SBI.csv')

# %% [markdown]
# **Now we are only interested in the closing price of the stock. Therefore, we will filter all the data from our training set and will retain only the values for the Close column**

# %%
sbi_data = sbi_data_raw.iloc[:, 7:8].values

# %%
sbi_data
# Out:
# array([[314.  ],
#        [315.6 ],
#        [312.8 ],
#        [299.9 ],
#        [301.4 ],
#        [305.25],
#        [303.  ],
#        [306.9 ],
#        [305.25],
#        [305.  ],
#        [318.4 ],
#        [315.25],
#        [313.2 ],
#        [318.  ],
#        [326.  ],
#        [325.2 ],
#        [327.05],
#        [331.45],
#        [333.4 ],
#        [326.45],
#        [309.3 ],
#        [308.5 ],
#        [299.65],
#        [292.55],
#        [290.5 ],
#        [291.2 ],
#        [279.5 ],
#        [289.75],
#        [286.2 ],
#        [286.1 ],
#        [307.7 ],
#        [306.5 ],
#        [305.65],
#        [300.5 ],
#        [302.2 ],
#        [295.  ],
#        [296.3 ],
#        [295.45],
#        [289.4 ],
#        [300.25],
#        [302.  ],
#        [301.6 ],
#        [302.8 ],
#        [292.75],
#        [293.6 ],
#        [290.35],
#        [288.5 ],
#        [285.45],
#        [286.7 ],
#        [281.  ],
#        [282.1 ],
#        [283.5 ],
#        [286.7 ],
#        [281.2 ],
#        [277.85],
#        [274.6 ],
#        [271.2 ],
#        [265.3 ],
#        [258.15],
#        [264.2 ],
#        [269.  ],
#        [266.2 ],
#        [274.1 ],
#        [274.1 ],
#        [272.  ],
#        [273.45],
#        [281.  ],
#        [285.85],
#        [285.5 ],
#        [290.  ],
#        [291.85],
#        [292.5 ],
#        [287.65],
#        [289.2 ],
#        [283.85],
#        [277.6 ],
#        [276.4 ],
#        [267.1 ],
#        [272.45],
#        [271.95],
#        [269.7 ],
#        [277.6 ],
#        [272.5 ],
#        [265.9 ],
#        [261.  ],
#        [262.4 ],
#        [275.5 ],
#        [267.55],
#        [274.4 ],
#        [281.5 ],
#        [287.  ],
#        [289.65],
#        [288.  ],
#        [292.3 ],
#        [291.5 ],
#        [281.9 ],
#        [277.2 ],
#        [277.6 ],
#        [281.2 ],
#        [278.3 ],
#        [278.6 ],
#        [278.2 ],
#        [266.5 ],
#        [258.25],
#        [257.7 ],
#        [257.4 ],
#        [254.85],
#        [258.  ],
#        [260.65],
#        [254.1 ],
#        [254.45],
#        [249.65],
#        [255.35],
#        [255.35],
#        [258.15],
#        [260.3 ],
#        [266.5 ],
#        [267.3 ],
#        [261.2 ],
#        [265.  ],
#        [265.4 ],
#        [260.3 ],
#        [263.  ],
#        [267.6 ],
#        [268.1 ],
#        [269.45],
#        [271.45],
#        [273.8 ],
#        [266.7 ],
#        [268.  ],
#        [270.45],
#        [273.5 ],
#        [268.05],
#        [268.6 ],
#        [272.4 ],
#        [271.65],
#        [267.1 ],
#        [264.5 ],
#        [268.75],
#        [270.05],
#        [263.7 ],
#        [258.5 ],
#        [259.25],
#        [253.65],
#        [257.85],
#        [269.3 ],
#        [281.25],
#        [289.  ],
#        [284.95],
#        [290.  ],
#        [281.95],
#        [282.5 ],
#        [267.9 ],
#        [256.15],
#        [260.4 ],
#        [268.5 ],
#        [279.2 ],
#        [284.75],
#        [278.4 ],
#        [270.  ],
#        [267.05],
#        [243.9 ],
#        [254.2 ],
#        [245.75],
#        [249.15],
#        [248.5 ],
#        [247.  ],
#        [239.3 ],
#        [230.35],
#        [231.85],
#        [225.  ],
#        [221.1 ],
#        [228.05],
#        [231.2 ],
#        [229.6 ],
#        [230.5 ],
#        [235.3 ],
#        [232.9 ],
#        [236.85],
#        [240.7 ],
#        [245.75],
#        [237.6 ],
#        [240.35],
#        [239.45],
#        [240.9 ],
#        [241.6 ],
#        [237.95],
#        [235.5 ],
#        [241.2 ],
#        [239.95],
#        [243.65],
#        [243.5 ],
#        [242.9 ],
#        [244.15],
#        [243.9 ],
#        [245.  ],
#        [249.05],
#        [256.8 ],
#        [254.05],
#        [254.8 ],
#        [249.4 ],
#        [253.15],
#        [251.4 ],
#        [248.4 ],
#        [241.7 ],
#        [237.  ],
#        [237.25],
#        [237.45],
#        [236.55],
#        [238.85],
#        [234.  ],
#        [243.9 ],
#        [245.65],
#        [241.3 ],
#        [243.2 ],
#        [240.3 ],
#        [249.  ],
#        [247.6 ],
#        [240.45],
#        [244.25],
#        [243.  ],
#        [242.6 ],
#        [241.6 ],
#        [243.5 ],
#        [249.6 ],
#        [248.65],
#        [249.95],
#        [244.55],
#        [241.5 ],
#        [241.75],
#        [238.9 ],
#        [235.4 ],
#        [235.  ],
#        [232.  ],
#        [227.2 ],
#        [225.6 ],
#        [226.  ],
#        [227.2 ],
#        [231.  ],
#        [226.25],
#        [230.5 ],
#        [228.65],
#        [229.75],
#        [228.5 ],
#        [228.6 ],
#        [228.4 ],
#        [225.95],
#        [224.75],
#        [227.75],
#        [221.1 ],
#        [217.75],
#        [217.  ],
#        [209.75],
#        [208.9 ],
#        [204.95],
#        [199.6 ],
#        [201.2 ],
#        [195.85],
#        [183.3 ],
#        [180.85],
#        [183.5 ],
#        [173.55],
#        [176.2 ],
#        [184.65],
#        [182.8 ],
#        [184.  ],
#        [185.75],
#        [179.55],
#        [172.9 ],
#        [168.9 ],
#        [166.85],
#        [164.  ],
#        [168.8 ],
#        [171.4 ],
#        [167.3 ],
#        [159.  ],
#        [154.6 ],
#        [154.45],
#        [167.4 ],
#        [156.35],
#        [159.65],
#        [159.  ],
#        [164.95],
#        [165.  ],
#        [158.6 ],
#        [156.65],
#        [152.  ],
#        [157.  ],
#        [159.45],
#        [162.8 ],
#        [182.4 ],
#        [183.6 ],
#        [189.1 ],
#        [183.1 ],
#        [183.45],
#        [180.35],
#        [180.55],
#        [181.7 ],
#        [185.05],
#        [185.6 ],
#        [185.2 ],
#        [191.5 ],
#        [197.05],
#        [197.9 ],
#        [196.25],
#        [188.7 ],
#        [189.3 ],
#        [197.05],
#        [194.  ],
#        [195.25],
#        [194.75],
#        [183.75],
#        [183.8 ],
#        [182.  ],
#        [183.45],
#        [188.45],
#        [188.  ],
#        [191.35],
#        [186.55],
#        [187.6 ],
#        [193.5 ],
#        [200.25],
#        [197.35],
#        [200.8 ],
#        [196.05],
#        [192.1 ],
#        [188.9 ],
#        [185.95],
#        [183.9 ],
#        [179.7 ],
#        [180.65],
#        [184.15],
#        [188.7 ],
#        [189.4 ],
#        [185.15],
#        [188.8 ],
#        [184.9 ],
#        [177.15],
#        [177.1 ],
#        [180.  ],
#        [172.45],
#        [171.7 ],
#        [168.45],
#        [170.05],
#        [174.75],
#        [184.55],
#        [201.3 ],
#        [197.8 ],
#        [205.3 ],
#        [198.6 ],
#        [200.6 ],
#        [196.25],
#        [198.75],
#        [210.15],
#        [209.9 ],
#        [209.5 ],
#        [206.1 ],
#        [202.5 ],
#        [208.2 ],
#        [215.25],
#        [215.15],
#        [212.9 ],
#        [215.25],
#        [213.5 ],
#        [212.9 ],
#        [217.8 ],
#        [211.  ],
#        [216.8 ],
#        [215.7 ],
#        [217.3 ],
#        [219.3 ],
#        [219.2 ],
#        [222.9 ],
#        [223.  ],
#        [220.15],
#        [218.2 ],
#        [224.5 ],
#        [226.75],
#        [226.75],
#        [231.75],
#        [231.  ],
#        [228.6 ],
#        [229.45],
#        [230.85],
#        [224.8 ],
#        [223.45],
#        [229.6 ],
#        [226.8 ],
#        [229.4 ],
#        [230.2 ],
#        [230.15],
#        [227.75],
#        [228.1 ],
#        [226.55],
#        [226.2 ],
#        [231.85],
#        [232.65],
#        [235.5 ],
#        [231.25],
#        [226.9 ],
#        [243.6 ],
#        [246.2 ],
#        [245.3 ],
#        [248.2 ],
#        [258.5 ],
#        [254.15],
#        [255.3 ],
#        [254.15],
#        [249.5 ],
#        [246.35],
#        [249.45],
#        [252.2 ],
#        [251.6 ],
#        [252.05],
#        [254.6 ],
#        [261.3 ],
#        [267.  ],
#        [267.8 ],
#        [263.7 ],
#        [253.65],
#        [257.65],
#        [256.35],
#        [255.2 ],
#        [255.6 ],
#        [253.85],
#        [251.6 ],
#        [257.9 ],
#        [254.25],
#        [251.9 ],
#        [248.85],
#        [254.  ],
#        [249.  ],
#        [252.  ],
#        [255.1 ],
#        [261.  ],
#        [260.  ],
#        [257.25],
#        [258.05],
#        [256.65],
#        [249.95],
#        [252.05],
#        [253.  ],
#        [256.9 ],
#        [255.3 ],
#        [260.1 ],
#        [259.2 ],
#        [262.8 ],
#        [261.5 ],
#        [257.  ],
#        [255.95],
#        [258.5 ],
#        [257.  ],
#        [259.4 ],
#        [251.  ],
#        [245.55],
#        [243.1 ],
#        [252.15],
#        [252.75],
#        [260.8 ],
#        [281.35],
#        [273.95],
#        [278.  ],
#        [277.65],
#        [278.7 ],
#        [275.7 ],
#        [258.5 ],
#        [258.  ],
#        [258.05],
#        [261.8 ],
#        [260.85],
#        [254.05],
#        [253.15],
#        [257.85],
#        [256.4 ],
#        [254.1 ],
#        [257.7 ],
#        [259.7 ],
#        [256.35],
#        [259.9 ],
#        [266.6 ],
#        [264.  ],
#        [266.05],
#        [263.  ],
#        [265.35],
#        [265.2 ],
#        [261.3 ],
#        [255.05],
#        [254.6 ],
#        [249.8 ],
#        [249.  ],
#        [243.95],
#        [248.6 ],
#        [247.6 ],
#        [247.2 ],
#        [250.3 ],
#        [243.55],
#        [244.9 ],
#        [243.2 ],
#        [245.5 ],
#        [246.05],
#        [246.7 ],
#        [248.9 ],
#        [251.7 ],
#        [251.15],
#        [251.  ],
#        [256.4 ],
#        [255.9 ],
#        [258.3 ],
#        [258.05],
#        [251.2 ],
#        [254.8 ],
#        [254.6 ],
#        [259.85],
#        [266.5 ],
#        [263.85],
#        [260.  ],
#        [271.4 ],
#        [272.75],
#        [278.1 ],
#        [276.55],
#        [277.6 ],
#        [278.7 ],
#        [276.1 ],
#        [275.2 ],
#        [271.5 ],
#        [269.6 ],
#        [269.3 ],
#        [270.4 ],
#        [269.5 ],
#        [269.5 ],
#        [270.75],
#        [271.7 ],
#        [270.5 ],
#        [268.2 ],
#        [269.  ],
#        [271.7 ],
#        [267.2 ],
#        [265.55],
#        [270.2 ],
#        [267.7 ],
#        [270.05],
#        [273.15],
#        [271.9 ],
#        [274.75],
#        [276.55],
#        [279.05],
#        [274.  ],
#        [273.9 ],
#        [272.75],
#        [267.75],
#        [268.65],
#        [275.95],
#        [278.9 ],
#        [282.2 ],
#        [288.7 ],
#        [291.4 ],
#        [293.3 ],
#        [293.4 ],
#        [297.  ],
#        [292.25],
#        [288.3 ],
#        [290.  ],
#        [294.3 ],
#        [290.25],
#        [292.  ],
#        [290.2 ],
#        [291.55],
#        [284.9 ],
#        [284.85],
#        [282.4 ],
#        [286.05],
#        [285.9 ],
#        [285.75],
#        [282.9 ],
#        [289.4 ],
#        [288.35],
#        [289.4 ],
#        [299.8 ],
#        [295.95],
#        [298.8 ],
#        [296.4 ],
#        [294.85],
#        [297.7 ],
#        [297.85],
#        [300.85],
#        [308.05],
#        [307.05],
#        [302.  ],
#        [308.95],
#        [294.4 ],
#        [288.85],
#        [283.25],
#        [290.  ],
#        [289.  ],
#        [283.6 ],
#        [288.5 ],
#        [288.15],
#        [287.85],
#        [287.2 ],
#        [287.25],
#        [287.4 ],
#        [290.9 ],
#        [288.45],
#        [288.45],
#        [284.65],
#        [283.45],
#        [284.4 ],
#        [283.85],
#        [285.95],
#        [287.7 ],
#        [290.2 ],
#        [290.6 ],
#        [293.7 ],
#        [288.95],
#        [280.  ],
#        [276.25],
#        [272.8 ],
#        [273.55],
#        [275.3 ],
#        [273.3 ],
#        [275.15],
#        [280.85],
#        [279.9 ],
#        [285.3 ],
#        [283.75],
#        [287.8 ],
#        [288.35],
#        [291.5 ],
#        [293.25],
#        [290.5 ],
#        [293.95],
#        [291.3 ],
#        [290.8 ],
#        [294.5 ],
#        [296.45],
#        [296.  ],
#        [298.35],
#        [299.2 ],
#        [312.8 ],
#        [309.25],
#        [305.6 ],
#        [300.65],
#        [305.8 ],
#        [310.6 ],
#        [305.  ],
#        [301.35],
#        [298.  ],
#        [280.35],
#        [277.8 ],
#        [283.2 ],
#        [280.8 ],
#        [278.3 ],
#        [274.55],
#        [274.05],
#        [278.7 ],
#        [280.1 ],
#        [279.3 ],
#        [276.35],
#        [276.65],
#        [278.5 ],
#        [278.  ],
#        [277.45],
#        [276.6 ],
#        [274.1 ],
#        [273.95],
#        [271.5 ],
#        [270.6 ],
#        [273.6 ],
#        [272.95],
#        [274.4 ],
#        [271.5 ],
#        [270.  ],
#        [267.65],
#        [269.5 ],
#        [268.65],
#        [262.1 ],
#        [258.5 ],
#        [258.15],
#        [250.25],
#        [252.95],
#        [254.25],
#        [251.4 ],
#        [253.35],
#        [252.1 ],
#        [257.2 ],
#        [256.8 ],
#        [257.  ],
#        [251.2 ],
#        [250.65],
#        [252.1 ],
#        [252.05],
#        [251.35],
#        [244.5 ],
#        [242.2 ],
#        [246.05],
#        [254.9 ],
#        [322.95],
#        [318.3 ],
#        [310.6 ],
#        [313.  ],
#        [306.55],
#        [320.  ],
#        [314.2 ],
#        [326.  ],
#        [328.  ],
#        [317.25],
#        [312.55],
#        [315.  ],
#        [333.8 ],
#        [331.  ],
#        [329.05],
#        [326.1 ],
#        [333.95],
#        [336.7 ],
#        [332.75],
#        [330.3 ],
#        [335.5 ],
#        [335.95],
#        [332.1 ],
#        [336.8 ],
#        [331.9 ],
#        [327.8 ],
#        [321.3 ],
#        [312.9 ],
#        [314.25],
#        [320.4 ],
#        [312.2 ],
#        [316.25],
#        [313.2 ],
#        [318.05],
#        [318.  ],
#        [313.35],
#        [313.85],
#        [312.35],
#        [318.7 ],
#        [320.  ],
#        [317.35],
#        [316.3 ],
#        [319.1 ],
#        [317.  ],
#        [313.45],
#        [308.3 ],
#        [310.  ],
#        [306.75],
#        [303.  ],
#        [302.8 ],
#        [309.25],
#        [307.25],
#        [306.05],
#        [303.9 ],
#        [301.05],
#        [302.15],
#        [302.5 ],
#        [302.4 ],
#        [297.2 ],
#        [308.1 ],
#        [304.8 ],
#        [308.8 ],
#        [306.3 ],
#        [318.55],
#        [330.45],
#        [311.9 ],
#        [313.  ],
#        [313.5 ],
#        [314.5 ],
#        [305.4 ],
#        [295.8 ],
#        [299.  ],
#        [294.6 ],
#        [292.1 ],
#        [302.25],
#        [295.4 ],
#        [290.1 ],
#        [275.5 ],
#        [279.1 ],
#        [271.4 ],
#        [269.6 ],
#        [269.5 ],
#        [273.15],
#        [272.5 ],
#        [276.4 ],
#        [274.3 ],
#        [267.7 ],
#        [267.95],
#        [262.2 ],
#        [263.15],
#        [255.35],
#        [246.7 ],
#        [256.65],
#        [253.65],
#        [253.55],
#        [254.1 ],
#        [257.8 ],
#        [253.25],
#        [252.7 ],
#        [247.9 ],
#        [250.  ],
#        [247.45],
#        [241.5 ],
#        [234.7 ],
#        [247.2 ],
#        [253.4 ],
#        [249.25],
#        [246.  ],
#        [250.95],
#        [246.7 ],
#        [260.8 ],
#        [258.75],
#        [259.85],
#        [263.15],
#        [257.4 ],
#        [253.9 ],
#        [250.8 ],
#        [249.  ],
#        [248.15],
#        [247.  ],
#        [246.7 ],
#        [241.85],
#        [242.4 ],
#        [240.7 ],
#        [237.5 ],
#        [233.25],
#        [243.2 ],
#        [246.05],
#        [241.2 ],
#        [241.6 ],
#        [241.75],
#        [247.2 ],
#        [250.3 ],
#        [248.1 ],
#        [247.1 ],
#        [250.8 ],
#        [252.4 ],
#        [246.55],
#        [242.9 ],
#        [242.55],
#        [239.6 ],
#        [244.5 ],
#        [255.7 ],
#        [263.45],
#        [268.8 ],
#        [267.  ],
#        [271.95],
#        [263.65],
#        [266.95],
#        [270.  ],
#        [267.  ],
#        [263.2 ],
#        [263.25],
#        [270.25],
#        [269.55],
#        [273.  ],
#        [273.6 ],
#        [284.  ],
#        [287.3 ],
#        [282.85],
#        [277.85],
#        [276.6 ],
#        [272.5 ],
#        [273.2 ],
#        [268.8 ],
#        [273.  ],
#        [268.5 ],
#        [267.  ],
#        [261.05],
#        [257.6 ],
#        [259.2 ],
#        [260.  ],
#        [258.  ],
#        [257.4 ],
#        [256.6 ],
#        [256.55],
#        [261.35],
#        [263.2 ],
#        [259.05],
#        [262.  ],
#        [257.35],
#        [251.1 ],
#        [258.95],
#        [260.5 ],
#        [260.3 ],
#        [262.7 ],
#        [266.6 ],
#        [266.65],
#        [271.35],
#        [289.25],
#        [286.55],
#        [296.5 ],
#        [293.6 ],
#        [294.3 ],
#        [294.  ],
#        [299.9 ],
#        [308.9 ],
#        [303.9 ],
#        [309.85],
#        [317.65],
#        [302.7 ],
#        [296.7 ],
#        [295.  ],
#        [293.  ],
#        [302.2 ],
#        [307.6 ],
#        [307.1 ],
#        [302.45],
#        [300.6 ],
#        [306.95],
#        [305.8 ],
#        [309.85],
#        [308.9 ],
#        [310.3 ],
#        [305.65],
#        [296.25],
#        [296.9 ],
#        [294.9 ],
#        [291.1 ],
#        [284.5 ],
#        [282.  ],
#        [285.85],
#        [290.65],
#        [285.1 ],
#        [273.6 ],
#        [271.15],
#        [270.45],
#        [263.35],
#        [272.5 ],
#        [263.  ],
#        [265.5 ],
#        [265.5 ],
#        [274.1 ],
#        [271.5 ],
#        [269.4 ],
#        [258.3 ],
#        [266.  ],
#        [262.75],
#        [277.3 ],
#        [261.7 ],
#        [263.7 ],
#        [263.15],
#        [270.35],
#        [261.  ],
#        [261.15],
#        [260.  ],
#        [255.9 ],
#        [255.9 ],
#        [250.65],
#        [247.9 ],
#        [267.5 ],
#        [273.9 ],
#        [280.75],
#        [285.65],
#        [285.55],
#        [296.1 ],
#        [285.25],
#        [287.  ],
#        [283.1 ],
#        [277.2 ],
#        [279.4 ],
#        [283.05],
#        [285.  ],
#        [291.55],
#        [288.05],
#        [282.6 ],
#        [286.5 ],
#        [282.65],
#        [286.5 ],
#        [289.  ],
#        [284.  ],
#        [288.  ],
#        [284.05],
#        [287.1 ],
#        [282.6 ],
#        [280.2 ],
#        [275.6 ],
#        [276.  ],
#        [274.35],
#        [281.75],
#        [285.3 ],
#        [288.85],
#        [288.7 ],
#        [290.25],
#        [293.9 ],
#        [299.5 ],
#        [294.  ],
#        [292.  ],
#        [293.5 ],
#        [294.55],
#        [293.3 ],
#        [294.45],
#        [295.65]])

# %% [markdown]
# **We will use MinMaxScaler to scale our data between 0 and 1**

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range = (0, 1))

sbi = scaler.fit_transform(sbi_data)

# %% [markdown]
# **Now we are going to predict the closing stock price of the data based on the closing stock prices for the past 60 days**

# %%
features_set = []
labels = []
for i in range(60, 988):
    features_set.append(sbi[i-60:i, 0])
    labels.append(sbi[i, 0])

# %% [markdown]
# **There are 988 records in the training data. We execute a loop that starts from 61st record and stores all the previous 60 records to the feature_set list. The 61st record is stored in the labels list**

# %% [markdown]
# **We need to convert both the feature_set and the labels list to the numpy array before we can use it for training**

# %%
features_set, labels = np.array(features_set), np.array(labels)

# %% [markdown]
# **In order to train LSTM on our data, we need to convert our data into the shape accepted by the LSTM. We need to convert our data into three-dimensional format. The first dimension is the number of records or rows in the dataset which is 988 in our case. The second dimension is the number of time steps which is 60 while the last dimension is the number of indicators. Since we are only using one feature, i.e Close, the number of indicators will be one**

# %%
features_set = np.reshape(features_set, (features_set.shape[0], features_set.shape[1], 1))

# %% [markdown]
# **We will add four LSTM layers to our model followed by a dense layer that predicts the future stock price**

# %% [markdown]
# **Instantiate the Sequential class**

# %%
model = Sequential()

# %% [markdown]
# ### Creating LSTM and Dropout Layers

# %%
model.add(LSTM(units=50, return_sequences=True, input_shape=(features_set.shape[1], 1)))
# Out:
# WARNING:tensorflow:From C:\Users\ALI\Anaconda3\lib\site-packages\tensorflow\python\ops\resource_variable_ops.py:435: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %%
model.add(Dropout(0.2))

# %% [markdown]
# ### Adding 3 more LSTM Layers

# %%
model.add(LSTM(units=50, return_sequences=True))
model.add(Dropout(0.2))

model.add(LSTM(units=50, return_sequences=True))
model.add(Dropout(0.2))

model.add(LSTM(units=50))
model.add(Dropout(0.2))

# %% [markdown]
# **To make our model more robust, we add a dense layer at the end of the model**

# %%
model.add(Dense(units = 1))

# %% [markdown]
# **We use the mean squared error as loss function and to reduce the loss or to optimize the algorithm, we use the adam optimizer**

# %%
model.compile(optimizer = 'adam', loss = 'mean_squared_error')

# %% [markdown]
# ## Algorithm Training

# %%
model.fit(features_set, labels, epochs = 100, batch_size = 32)
# Out:
# WARNING:tensorflow:From C:\Users\ALI\Anaconda3\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Epoch 1/100
# 928/928 [==============================] - 6s 6ms/step - loss: 0.0740
# Epoch 2/100
# 928/928 [==============================] - 3s 4ms/step - loss: 0.0168
# Epoch 3/100
# 928/928 [==============================] - 3s 3ms/step - loss: 0.0123
# Epoch 4/100
# 928/928 [==============================] - 3s 4ms/step - loss: 0.0121
# Epoch 5/100
# 928/928 [==============================] - 3s 4ms/step - loss: 0.0114
# Epoch 6/100
# 928/928 [==============================] - 4s 5ms/step - loss: 0.0110
# Epoch 7/100
# 928/928 [==============================] - 5s 5ms/step - loss: 0.0102
# Epoch 8/100
# 928/928 [==============================] - 4s 4ms/step - loss: 0.0097
# Epoch 9/100
# 928/928 [==============================] - 4s 4ms/step - loss: 0.0088
# Epoch 10/100
# 928/928 [==============================] - 3s 4ms/step - loss: 0.0091
# Epoch 11/100
# 928/928 [==============================] - 4s 4ms/step - loss: 0.0087
# Epoch 12/100
# 928/928 [==============================] - 5s 5ms/step - loss: 0.0084
# Epoch 13/100
# 928/928 [==============================] - 5s 6ms/step - loss: 0.0096
# Epoch 14/100
# 928/928 [==============================] - 3s 3ms/step - loss: 0.0080
# Epoch 15/100
# 928/928 [==============================] - 3s 4ms/step - loss: 0.0079
# Epoch 16/100
# 928/928 [==============================] - 3s 4ms/step - loss: 0.0075
# Epoch 17/100
# 928/928 [==============================] - 3s 4ms/step - loss: 0.0070
# Epoch 18/100
# 928/928 [==============================] - 5s 6ms/step - loss: 0.0068
# Epoch 19/100
# 928/928 [==============================] - 7s 8ms/step - loss: 0.0067
# Epoch 20/100
# 928/928 [==============================] - 3s 4ms/step - loss: 0.0068
# Epoch 21/100
# 928/928 [==============================] - 3s 4ms/step - loss: 0.0071
# Epoch 22/100
# 928/928 [==============================] - 3s 3ms/step - loss: 0.0081
# Epoch 23/100
# 928/928 [==============================] - 3s 4ms/step - loss: 0.0070
# Epoch 24/100
# 928/928 [==============================] - 6s 6ms/step - loss: 0.0061
# Epoch 25/100
# 928/928 [==============================] - 5s 6ms/step - loss: 0.0063
# Epoch 26/100
# 928/928 [==============================] - 3s 3ms/step - loss: 0.0063
# Epoch 27/100
# 928/928 [==============================] - 3s 3ms/step - loss: 0.0061
# Epoch 28/100
# 928/928 [==============================] - 3s 3ms/step - loss: 0.0055
# Epoch 29/100
# 928/928 [==============================] - 3s 3ms/step - loss: 0.0058
# Epoch 30/100
# 928/928 [==============================] - 5s 6ms/step - loss: 0.0070
# Epoch 31/100
# 928/928 [==============================] - 6s 6ms/step - loss: 0.0052
# Epoch 32/100
# 928/928 [==============================] - 3s 3ms/step - loss: 0.0050
# Epoch 33/100
# 928/928 [==============================] - 3s 3ms/step - loss: 0.0050
# Epoch 34/100
# 928/928 [==============================] - 3s 3ms/step - loss: 0.0051
# Epoch 35/100
# 928/928 [==============================] - 4s 4ms/step - loss: 0.0052
# Epoch 36/100
# 928/928 [==============================] - 7s 7ms/step - loss: 0.0051
# Epoch 37/100
# 928/928 [==============================] - 5s 6ms/step - loss: 0.0054
# Epoch 38/100
# 928/928 [==============================] - 3s 4ms/step - loss: 0.0054
# Epoch 39/100
# 928/928 [==============================] - 3s 4ms/step - loss: 0.0047
# Epoch 40/100
# 928/928 [==============================] - 4s 4ms/step - loss: 0.0047
# Epoch 41/100
# 928/928 [==============================] - 5s 5ms/step - loss: 0.0048
# Epoch 42/100
# 928/928 [==============================] - 7s 8ms/step - loss: 0.0048
# Epoch 43/100
# 928/928 [==============================] - 3s 4ms/step - loss: 0.0046
# Epoch 44/100
# 928/928 [==============================] - 3s 4ms/step - loss: 0.0049
# Epoch 45/100
# 928/928 [==============================] - 3s 3ms/step - loss: 0.0044
# Epoch 46/100
# 928/928 [==============================] - 5s 6ms/step - loss: 0.0046
# Epoch 47/100
# 928/928 [==============================] - 9s 10ms/step - loss: 0.0044
# Epoch 48/100
# 928/928 [==============================] - 4s 4ms/step - loss: 0.0048
# Epoch 49/100
# 928/928 [==============================] - 4s 4ms/step - loss: 0.0044
# Epoch 50/100
# 928/928 [==============================] - 4s 4ms/step - loss: 0.0043
# Epoch 51/100
# 928/928 [==============================] - 5s 5ms/step - loss: 0.0041
# Epoch 52/100
# 928/928 [==============================] - 8s 9ms/step - loss: 0.0046
# Epoch 53/100
# 928/928 [==============================] - 3s 3ms/step - loss: 0.0042
# Epoch 54/100
# 928/928 [==============================] - 3s 3ms/step - loss: 0.0042
# Epoch 55/100
# 928/928 [==============================] - 3s 3ms/step - loss: 0.0039
# Epoch 56/100
# 928/928 [==============================] - 3s 3ms/step - loss: 0.0037
# Epoch 57/100
# 928/928 [==============================] - 7s 8ms/step - loss: 0.0036
# Epoch 58/100
# 928/928 [==============================] - 6s 6ms/step - loss: 0.0037
# Epoch 59/100
# 928/928 [==============================] - 3s 4ms/step - loss: 0.0039
# Epoch 60/100
# 928/928 [==============================] - 3s 4ms/step - loss: 0.0039
# Epoch 61/100
# 928/928 [==============================] - 3s 4ms/step - loss: 0.0038
# Epoch 62/100
# 928/928 [==============================] - 5s 5ms/step - loss: 0.0034
# Epoch 63/100
# 928/928 [==============================] - 8s 9ms/step - loss: 0.0037
# Epoch 64/100
# 928/928 [==============================] - 3s 4ms/step - loss: 0.0035
# Epoch 65/100
# 928/928 [==============================] - 3s 4ms/step - loss: 0.0035
# Epoch 66/100
# 928/928 [==============================] - 3s 4ms/step - loss: 0.0034
# Epoch 67/100
# 928/928 [==============================] - 3s 3ms/step - loss: 0.0035
# Epoch 68/100
# 928/928 [==============================] - 8s 8ms/step - loss: 0.0033
# Epoch 69/100
# 928/928 [==============================] - 5s 5ms/step - loss: 0.0031
# Epoch 70/100
# 928/928 [==============================] - 3s 4ms/step - loss: 0.0031
# Epoch 71/100
# 928/928 [==============================] - 3s 3ms/step - loss: 0.0033
# Epoch 72/100
# 928/928 [==============================] - 3s 3ms/step - loss: 0.0031
# Epoch 73/100
# 928/928 [==============================] - 5s 5ms/step - loss: 0.0033
# Epoch 74/100
# 928/928 [==============================] - 8s 9ms/step - loss: 0.0034
# Epoch 75/100
# 928/928 [==============================] - 3s 3ms/step - loss: 0.0030
# Epoch 76/100
# 928/928 [==============================] - 3s 4ms/step - loss: 0.0028
# Epoch 77/100
# 928/928 [==============================] - 3s 4ms/step - loss: 0.0029
# Epoch 78/100
# 928/928 [==============================] - 3s 4ms/step - loss: 0.0029
# Epoch 79/100
# 928/928 [==============================] - 7s 7ms/step - loss: 0.0029
# Epoch 80/100
# 928/928 [==============================] - 6s 6ms/step - loss: 0.0027
# Epoch 81/100
# 928/928 [==============================] - 3s 3ms/step - loss: 0.0029
# Epoch 82/100
# 928/928 [==============================] - 3s 3ms/step - loss: 0.0029
# Epoch 83/100
# 928/928 [==============================] - 3s 4ms/step - loss: 0.0028
# Epoch 84/100
# 928/928 [==============================] - 4s 5ms/step - loss: 0.0026
# Epoch 85/100
# 928/928 [==============================] - 8s 9ms/step - loss: 0.0028
# Epoch 86/100
# 928/928 [==============================] - 3s 4ms/step - loss: 0.0029
# Epoch 87/100
# 928/928 [==============================] - 3s 4ms/step - loss: 0.0027
# Epoch 88/100
# 928/928 [==============================] - 3s 3ms/step - loss: 0.0029
# Epoch 89/100
# 928/928 [==============================] - 3s 4ms/step - loss: 0.0025
# Epoch 90/100
# 928/928 [==============================] - 11s 11ms/step - loss: 0.0026
# Epoch 91/100
# 928/928 [==============================] - 3s 4ms/step - loss: 0.0028
# Epoch 92/100
# 928/928 [==============================] - 3s 4ms/step - loss: 0.0027
# Epoch 93/100
# 928/928 [==============================] - 3s 4ms/step - loss: 0.0027
# Epoch 94/100
# 928/928 [==============================] - 4s 4ms/step - loss: 0.0027
# Epoch 95/100
# 928/928 [==============================] - 11s 12ms/step - loss: 0.0024
# Epoch 96/100
# 928/928 [==============================] - 3s 4ms/step - loss: 0.0023
# Epoch 97/100
# 928/928 [==============================] - 4s 4ms/step - loss: 0.0023
# Epoch 98/100
# 928/928 [==============================] - 4s 4ms/step - loss: 0.0025
# Epoch 99/100
# 928/928 [==============================] - 5s 6ms/step - loss: 0.0027
# Epoch 100/100
# 928/928 [==============================] - 8s 9ms/step - loss: 0.0024

# %% [markdown]
# ## Testing our LSTM

# %% [markdown]
# **We have successfully trained our LSTM, now is the time to test the performance of our algorithm on the test set by predicting the closing stock prices for the month of January 2019**

# %% [markdown]
# **Again we will use NSEpy API to fetch data and then store it in as a dataframe**

# %%
from datetime import date
from nsepy import get_history
sbin = get_history(symbol='SBIN',
                   start=date(2019,1,1),
                   end=date(2019,1,30))

# %%
sbin
# Out:
#            Symbol Series  Prev Close    Open    High     Low    Last   Close  \
# Date
# 2019-01-01   SBIN     EQ      295.90  297.50  300.70  293.85  300.70  299.60
# 2019-01-02   SBIN     EQ      299.60  299.10  302.50  293.10  293.80  293.90
# 2019-01-03   SBIN     EQ      293.90  295.00  295.55  290.10  291.05  291.10
# 2019-01-04   SBIN     EQ      291.10  292.10  299.00  291.50  297.30  297.65
# 2019-01-07   SBIN     EQ      297.65  301.05  301.50  295.20  296.55  296.30
# 2019-01-08   SBIN     EQ      296.30  295.80  306.00  294.75  305.50  305.30
# 2019-01-09   SBIN     EQ      305.30  306.00  307.10  300.75  304.75  305.30
# 2019-01-10   SBIN     EQ      305.30  305.10  307.50  303.50  305.40  305.55
# 2019-01-22       0.2780
# 2019-01-23       0.2233
# 2019-01-24       0.3456
# 2019-01-25       0.2821
# 2019-01-28       0.4475
# 2019-01-29       0.3874
# 2019-01-30       0.2635

# %%
sbin.to_csv('sbi_test.csv')

# %%
sbi_test_raw = pd.read_csv('sbi_test.csv')

# %%
sbi_test = sbi_test_raw.iloc[:, 7:8].values

# %% [markdown]
# **For each day of January 2019, we want our feature set to contain the opening stock prices for the previous 60 days. For the 1st of January, we need the stock prices for the previous 60 days. To do so, we need to concatenate our training data and test data before preprocessing**

# %%
sbi_total = pd.concat((sbi_data_raw['Close'], sbi_test_raw['Close']), axis=0)

# %%
sbi_total
# Out:
# 0      314.00
# 1      315.25
# 2      312.75
# 3      299.90
# 4      300.15
# 5      304.85
# 6      303.20
# 7      307.10
# 8      305.10
# 9      304.70
# 10     320.30
# 11     315.45
# 12     313.15
# 13     318.15
# 14     326.20
# 15     324.65
# 16     327.45
# 17     330.05
# 18     334.60
# 19     327.00
# 20     308.95
# 21     307.50
# 22     300.30
# 23     293.05
# 24     290.80
# 25     290.30
# 26     279.50
# 27     287.30
# 28     285.95
# 29     284.30
#         ...
# 981    300.70
# 982    294.05
# 983    291.90
# 984    293.05
# 985    294.15
# 986    292.15
# 987    294.80
# 988    295.90
# 0      299.60
# 1      293.90
# 2      291.10
# 3      297.65
# 4      296.30
# 5      305.30
# 6      305.30
# 7      305.55
# 8      302.75
# 9      300.40
# 10     301.65
# 11     303.15
# 12     297.40
# 13     294.95
# 14     292.45
# 15     290.25
# 16     286.65
# 17     288.05
# 18     285.40
# 19     281.60
# 20     280.60
# 21     287.45
# Name: Close, Length: 1011, dtype: float64

# %% [markdown]
# **The input for each day should contain the opening stock prices for the previous 60 days. That means we need opening stock prices for the 20 test days for the month of January 2019 and the 60 stock prices from the last 60 days for the training set**

# %%
test_inputs = sbi_total[len(sbi_total) - len(sbi_test) - 60:].values

# %% [markdown]
# **As we did for the training set, we need to scale our test data**

# %%
test_inputs = test_inputs.reshape(-1,1)
test_inputs = scaler.transform(test_inputs)

# %% [markdown]
# **Let's prepare our final test input set that will contain previous 60 stock prices for the month of January**

# %%
test_features = []
for i in range(60, 80):
    test_features.append(test_inputs[i-60:i, 0])

# %% [markdown]
# **Now we need to convert our data into the three-dimensional format which can be used as input to the LSTM**

# %%
test_features = np.array(test_features)
test_features = np.reshape(test_features, (test_features.shape[0], test_features.shape[1], 1))

# %% [markdown]
# ## Making Predictions

# %%
predictions = model.predict(test_features)

# %% [markdown]
# **Since we scaled our data, the predictions made by the LSTM are also scaled. We need to reverse the scaled prediction back to their actual values**

# %%
predictions = scaler.inverse_transform(predictions)

# %% [markdown]
# ## Plotting the predictions and Comparision

# %%
plt.figure(figsize=(10,6))
plt.plot(sbi_test, color='blue', label='Actual SBI Stock Price')
plt.plot(predictions , color='red', label='Predicted SBI Stock Price')
plt.title('SBI Stock Price Prediction')
plt.xlabel('Date')
plt.ylabel('SBI Stock Price')
plt.legend()
plt.show()

# %% [markdown]
# ## Findings

# %% [markdown]
# **Hence we conclude that LSTM model is more effective than Regression Models in the case of Stock Market Prediction**
